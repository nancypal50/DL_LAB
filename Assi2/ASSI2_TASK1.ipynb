# %% [markdown]
# ### NANCY PAL 20MAI0050

# %% [markdown]
# ## https://github.com/nancypal50/DL_LAB/tree/main/Assi2

# %% [markdown]
# # Task 1 - Demonstrating Activation Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
from IPython.display import Image
Image(filename='E:/vit2020/sem 2/DL/Lab_dataset/Activation Function.png')

# %% [markdown]
# ### Binary Step Activation Function
#  -Binary step function returns value either 0 or 1.
#
#     -It returns '0' if the input is the less then zero
#     -It returns '1' if the input is greater than zero

# %%
def binaryStep(x):
    return np.heaviside(x,1)

# %%
x = np.linspace(-5, 5)
plt.plot(x, binaryStep(x))
plt.axis('tight')
plt.title('Activation Function :binaryStep')
plt.show()

# %% [markdown]
# ### Linear Activation Function
#     -It returns what it gets as input.

# %%
def linear(x):
    return x

# %%
x = np.linspace(-5, 5)
plt.plot(x, linear(x))
plt.axis('tight')
plt.title('Activation Function :Linear')
plt.show()

# %% [markdown]
# ### Sigmoid Activation Function
#     -Sigmoid function returns the value beteen 0 and 1.

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
x = np.linspace(-10, 10)
plt.plot(x, sigmoid(x))
plt.axis('tight')
plt.title('Activation Function :Sigmoid')
plt.show()

# %% [markdown]
# ### Tanh Activation Function
#     -Tanh is a nonlinear activation function. Tanh outputs between -1 and 1.

# %%
def tanh(x):
    return np.tanh(x)

# %%
x = np.linspace(-20, 20)
plt.plot(x, tanh(x))
plt.axis('tight')
plt.title('Activation Function :Tanh')
plt.show()

# %% [markdown]
# ### RELU Activation Function
#     -RELU is a non linear activation functions.
#
#         -RELU returns 0 if the x (input) is less than 0
#         -RELU returns x if the x (input) is greater than 0

# %%
X = np.arange(-10, 10, .2)

def relu(x):
    return np.maximum(0, x)

relu1 = relu(X)

plt.plot(X, relu1)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Activation Function :RELU')
plt.show()

# %% [markdown]
# ### ELU
#     -With Exponential Linear Units (ELU), we can have a mean activation that is close to 0 and it is an exponential
#     function. ELU does not saturate for large values of x.
#     -it acts like a ReLU unit if x is positive, but for negative values it is a function bounded by a fixed value -1,
#     for α=1.

# %%
X = np.arange(-10, 10, .2)
def elu(arr, alpha):
    a = []
    for x in arr:
        if x >= 0:
            a.append(x)
        else:
            a.append(alpha * (np.exp(x)-1))
    return a

elu1 = elu(X, 1.0)

plt.plot(X, elu1)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Activation Function :ELU')
plt.show()

# %%
X = np.arange(-10, 10, .2)
def leaky_relu_function(arr):
    a = []
    for x in arr:
        if x<0:
            a.append(0.01*x)
        else:
            a.append(x)
    return a
Lrelu1 = leaky_relu_function(X)

plt.plot(X, Lrelu1)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Activation Function :ELU')
plt.show()

# %% [markdown]
# ### Softmax Activation Function
#     -Softmax turns logits, the numeric output of the last linear layer of a multi-class classification neural network
#      into probabilities.

# %%
def softmax(x):
    return np.exp(x) / np.sum(np.exp(x), axis=0)

# %%
x = np.linspace(-15, 15)
plt.plot(x, softmax(x))
plt.axis('tight')
plt.title('Activation Function :Softmax')
plt.show()
